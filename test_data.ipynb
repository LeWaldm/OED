# %%
from tissue import Tissue
import data_utils as dutils
import model_utils as mutils
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# test: simple Gaussian process 2d
data = dutils.Simulated_GP_2d()
X,Y = data.get_data()
designs = data.designs_discrete()
best_designs, X_fragment_idx = mutils.fit_GP(X,Y,designs,5)
data.plot_slices(X_fragment_idx)
# Out:
# 1/5: 49.96197682737985, [-3.27586207 -2.50981075]
# 2/5: 44.00998090278555, [ 5.         -2.50981075]
# 3/5: 41.27268033089029, [-4.65517241 -1.47488966]
# 4/5: 44.1782961049398, [-0.17241379 -2.50981075]

# %%
# test: simple Gaussian process 3d
datamodule = dutils.Simulated_GP_3d()
designs = datamodule.designs_all()
chosen_designs, observed_idx = mutils.fit_GP_3d(
    datamodule, designs=designs,n_experimental_iters=3
)
data.plot_slices(chosen_designs, observed_idx)
